# %%
import pandas as pd

# %% [markdown]
# # Dataframe e ordenação
#
# **Utilizando o arquivo: carros.csv**
#
# 1. Faça o upload do CSV carros.csv
# 2. Print seu head com 10 linhas
# 3. Agora print as colunas e index do dataframe
# 4. Faça um sort decrescente no dataframe pelo estado com maior quantidade de carros
# 5. Descubra qual a proporção de carro para a população de cada estado e insira em uma nova coluna
# 6. Faça um dataframe com Estado e proporção de carro por habitante

# %%
df = pd.read_csv('carros.csv')
df.head()
# Out:
#          Região    Estado  Quant Carros  Quant Carros Família com Filhos  \
# 0           Sul      Acre          4342                             1034
# 1  Centro-Oeste   Alagoas         18991                             3253
# 2       Sudeste     Amapá          6463                             4152
# 3  Centro-Oeste  Amazonas          3180                             2955
# 4  Centro-Oeste     Bahia         11288                             2585
#
#    População do Estado  Carros por habitante
# 0              23942.0              0.181355
# 1              23431.0              0.810507
# 2               7747.0              0.834258
# 3               5189.0              0.612835
# 4              24118.0              0.468032

# %%
df.head(10)
# Out:
#          Região            Estado  Quant Carros  \
# 0           Sul              Acre          4342
# 1  Centro-Oeste           Alagoas         18991
# 2       Sudeste             Amapá          6463
# 3  Centro-Oeste          Amazonas          3180
# 4  Centro-Oeste             Bahia         11288
# 5      Nordeste             Ceará         10807
# 6       Sudeste  Distrito Federal          5786
# 7       Sudeste    Espírito Santo          5494
# 8       Sudeste             Goiás         24412
# 9  Centro-Oeste          Maranhão          8472
#
#    Quant Carros Família com Filhos  População do Estado  Carros por habitante
# 0                             1034              23942.0              0.181355
# 1                             3253              23431.0              0.810507
# 2                             4152               7747.0              0.834258
# 3                             2955               5189.0              0.612835
# ...

# %%
df.columns
# Out:
# Index(['Região', 'Estado', 'Quant Carros', 'Quant Carros Família com Filhos',
#        'População do Estado', 'Carros por habitante'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=27, step=1)

# %%
df.sort_values('Quant Carros',  ascending=False)
# Out:
#           Região               Estado  Quant Carros  \
# 18         Norte       Rio de Janeiro         33848
# 8        Sudeste                Goiás         24412
# 21  Centro-Oeste             Rondônia         23113
# 13      Nordeste                 Pará         22387
# 25       Sudeste              Sergipe         22307
# 1   Centro-Oeste              Alagoas         18991
# 12  Centro-Oeste         Minas Gerais         17291
# 26       Sudeste            Tocantins         17144
# 4   Centro-Oeste                Bahia         11288
# 5       Nordeste                Ceará         10807
# 14           Sul              Paraíba         10666
# 16           Sul           Pernambuco         10533
# 23         Norte       Santa Catarina          9466
# 9   Centro-Oeste             Maranhão          8472
# 17  Centro-Oeste                Piauí          7912
# 2        Sudeste                Amapá          6463
# 19           Sul  Rio Grande do Norte          6396
# ...

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df.columns
# Out:
# Index(['Região', 'Estado', 'Quant Carros', 'Quant Carros Família com Filhos',
#        'População do Estado', 'Carros por habitante'],
#       dtype='object')

# %%
df['Quant Carros']/df['População do Estado']
# Out:
# 0     0.181355
# 1     0.810507
# 2     0.834258
# 3     0.612835
# 4     0.468032
# 5     0.265053
# 6     0.838672
# 7     0.876655
# 8     0.667889
# 9     0.516774
# 10    0.568957
# 11    0.639258
# 12    0.371004
# 13    0.626385
# 14    0.546918
# 15    0.225417
# 16    0.674026
# 17    0.573666
# 18    0.700453
# 19    0.133192
# 20    0.166828
# 21    0.481511
# 22    0.222340
# 23    0.327577
# 24    0.829874
# 25    0.783169
# 26    0.773681
# dtype: float64

# %%
proporcao = df['Quant Carros']/df['População do Estado']
proporcao
# Out:
# 0     0.181355
# 1     0.810507
# 2     0.834258
# 3     0.612835
# 4     0.468032
# 5     0.265053
# 6     0.838672
# 7     0.876655
# 8     0.667889
# 9     0.516774
# 10    0.568957
# 11    0.639258
# 12    0.371004
# 13    0.626385
# 14    0.546918
# 15    0.225417
# 16    0.674026
# 17    0.573666
# 18    0.700453
# 19    0.133192
# 20    0.166828
# 21    0.481511
# 22    0.222340
# 23    0.327577
# 24    0.829874
# 25    0.783169
# 26    0.773681
# dtype: float64

# %%
df['Carros por habitante'] = proporcao

# %%
df.head()
# Out:
#          Região    Estado  Quant Carros  Quant Carros Família com Filhos  \
# 0           Sul      Acre          4342                             1034
# 1  Centro-Oeste   Alagoas         18991                             3253
# 2       Sudeste     Amapá          6463                             4152
# 3  Centro-Oeste  Amazonas          3180                             2955
# 4  Centro-Oeste     Bahia         11288                             2585
#
#    População do Estado  Carros por habitante
# 0              23942.0              0.181355
# 1              23431.0              0.810507
# 2               7747.0              0.834258
# 3               5189.0              0.612835
# 4              24118.0              0.468032

# %%
df_estado_hab = df[['Estado', 'Carros por habitante']]

# %%
df_estado_hab
# Out:
#                  Estado  Carros por habitante
# 0                  Acre              0.181355
# 1               Alagoas              0.810507
# 2                 Amapá              0.834258
# 3              Amazonas              0.612835
# 4                 Bahia              0.468032
# 5                 Ceará              0.265053
# 6      Distrito Federal              0.838672
# 7        Espírito Santo              0.876655
# 8                 Goiás              0.667889
# 9              Maranhão              0.516774
# 10          Mato Grosso              0.568957
# 11   Mato Grosso do Sul              0.639258
# 12         Minas Gerais              0.371004
# 13                 Pará              0.626385
# 14              Paraíba              0.546918
# 15               Paraná              0.225417
# 16           Pernambuco              0.674026
# 17                Piauí              0.573666
# 18       Rio de Janeiro              0.700453
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Agregação de dados
#
# **Utilizando o arquivos: concurso.csv**
# 7. Quantas pessoas são do estado do Piauí?
# 8. Qual a distribuição de escolaridade por estado?
# 9. Qual é a porcentagem de pessoas com deficiência?

# %%
import pandas as pd

# %%
df_concurso = pd.read_csv('dados_concurso.csv')

# %%
df_concurso.head()
# Out:
#                     Número de Inscrição Data de Nascimento  \
# 0  f2bf14e6-9ecc-43d1-9098-1a133277d26a                NaN
# 1  afd1d890-dbfd-4d72-a9a2-4309f356167a         1910-02-05
# 2  16451a82-28f8-48bf-a5b6-9f0c5b25ef6b                NaN
# 3  200731b4-a651-4a2d-9d01-11d4d6a41511         1949-11-21
# 4  22369508-74a2-403b-8237-1851971a08d6         1963-06-26
#
#      Data de Inscrição                Cidade Estado Sexo Deficiência  \
# 0  2022-01-11 16:47:41  da Mota de das Neves     MS    F         Sim
# 1  2022-01-30 13:17:53     Teixeira do Norte     SE  NaN         Não
# 2  2022-01-28 12:28:17                   NaN     CE    F         Sim
# 3  2022-01-20 02:11:07                 Porto     RN    F         Não
# 4  2022-01-23 21:48:36        Pires do Oeste     PA    F         Não
#
#            Nome Sobrenome        Escolaridade
# 0   João Miguel    Castro        Ensino Médio
# 1  Maria Sophia   Rezende  Ensino Fundamental
# 2      Giovanna   Freitas     Ensino Superior
# ...

# %%
# !pip install pandas

import pandas as pd

# %%
df_concurso[df_concurso['Estado'] == 'PI']['Número de Inscrição'].count()
# Out:
# 4

# %%
df_concurso[['Número de Inscrição', 'Estado']].groupby('Estado').count()
# Out:
#         Número de Inscrição
# Estado
# AL                        3
# AM                        1
# AP                        6
# BA                        3
# CE                        3
# DF                        2
# ES                        1
# GO                        4
# MA                        4
# MG                        3
# MS                        2
# MT                        3
# PA                        4
# PB                        3
# PE                        5
# PI                        4
# PR                        1
# RJ                        2
# RN                        5
# RO                        2
# RR                        1
# RS                        2
# SC                        3
# SE                        5
# SP                        4
# TO                        3

# %%
df_concurso[['Estado', 'Escolaridade', 'Número de Inscrição']].groupby(['Estado', 'Escolaridade']).count()
# Out:
#                            Número de Inscrição
# Estado Escolaridade
# AL     Ensino Fundamental                    1
#        Ensino Superior                       1
# AM     Ensino Superior                       1
# AP     Ensino Fundamental                    3
#        Ensino Médio                          2
# BA     Ensino Superior                       2
# CE     Ensino Fundamental                    1
#        Ensino Médio                          1
#        Ensino Superior                       1
# DF     Ensino Superior                       2
# ES     Ensino Superior                       1
# GO     Ensino Fundamental                    2
#        Ensino Médio                          2
# MA     Ensino Fundamental                    2
# MG     Ensino Fundamental                    1
#        Ensino Médio                          1
#        Ensino Superior                       1
# MS     Ensino Médio                          1
# ...

# %%
df_concurso['Deficiência'].value_counts(normalize=True)*100
# Out:
# Sim    52.941176
# Não    47.058824
# Name: Deficiência, dtype: float64

# %% [markdown]
# # Indexação e fatiamento
#
# **Utilizando o arquivos: concurso.csv**
#
# Temos como base inscrições em um concurso público, utilizando indexação retorne:
#
# 10. Retorne os dados com número de  inscrição, nome e data de nascimento.
#
# 11. Quantas pessoas nasceram antes de 1995?
#
# 13. Quais foram os 10 primeiros inscritos.

# %%
df_concurso.columns
# Out:
# Index(['Número de Inscrição', 'Data de Nascimento', 'Data de Inscrição',
#        'Cidade', 'Estado', 'Sexo', 'Deficiência', 'Nome', 'Sobrenome',
#        'Escolaridade'],
#       dtype='object')

# %%
df_concurso[['Número de Inscrição', 'Data de Nascimento', 'Nome']]
# Out:
#                      Número de Inscrição Data de Nascimento           Nome
# 0   f2bf14e6-9ecc-43d1-9098-1a133277d26a                NaN    João Miguel
# 1   afd1d890-dbfd-4d72-a9a2-4309f356167a         1910-02-05   Maria Sophia
# 2   16451a82-28f8-48bf-a5b6-9f0c5b25ef6b                NaN       Giovanna
# 3   200731b4-a651-4a2d-9d01-11d4d6a41511         1949-11-21    João Felipe
# 4   22369508-74a2-403b-8237-1851971a08d6         1963-06-26       Benjamin
# ..                                   ...                ...            ...
# 95  b162a88d-6afa-46aa-afbe-f5b0e0d13ce4                NaN           Cauê
# 96  25e9b106-2c3d-444d-b7d4-ae34ad33bc88                NaN  Maria Eduarda
# 97  4ffbc174-78af-4da1-a53a-b442c20a876e                NaN       Catarina
# 98  d4e8e12a-3298-4ff1-a80f-2946431bd5a7         1916-06-21       Giovanna
# 99  7af3e5da-99a2-4f0f-900c-cbc194351ce8         1959-03-14          Eloah
#
# [100 rows x 3 columns]

# %%
df_concurso.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Número de Inscrição  100 non-null    object
#  1   Data de Nascimento   82 non-null     object
#  2   Data de Inscrição    100 non-null    object
#  3   Cidade               79 non-null     object
#  4   Estado               79 non-null     object
#  5   Sexo                 84 non-null     object
#  6   Deficiência          85 non-null     object
#  7   Nome                 100 non-null    object
#  8   Sobrenome            100 non-null    object
#  9   Escolaridade         80 non-null     object
# dtypes: object(10)
# memory usage: 7.9+ KB

# %%
df_concurso['Data de Nascimento'] = pd.to_datetime(df_concurso['Data de Nascimento'])

# %%
import numpy as np

# %%
df_concurso['Data de Nascimento'].loc[df_concurso['Data de Nascimento']< np.datetime64('1995')]
# Out:
# 1    1910-02-05
# 3    1949-11-21
# 4    1963-06-26
# 7    1965-08-06
# 9    1923-04-18
# 10   1968-05-11
# 13   1967-03-24
# 14   1948-06-13
# 16   1923-08-12
# 17   1988-10-28
# 18   1929-04-16
# 20   1951-07-24
# 22   1928-02-08
# 23   1984-03-04
# 26   1971-04-10
# 27   1925-07-31
# 28   1977-12-08
# 30   1941-09-25
# 32   1989-12-05
# 33   1936-07-23
# 34   1992-09-11
# 35   1977-08-07
# 36   1964-06-25
# 37   1953-09-15
# 38   1950-06-18
# 40   1943-10-09
# 42   1947-11-26
# 43   1988-01-02
# 44   1939-12-28
# 45   1962-10-18
# 47   1981-10-27
# 48   1945-09-21
# 49   1916-09-23
# 50   1958-03-22
# 51   1939-06-08
# 53   1959-06-23
# 54   1988-08-17
# 55   1965-09-07
# 56   1967-06-04
# 61   1966-11-14
# 62   1970-02-27
# 65   1915-11-03
# 67   1965-02-06
# 68   1950-08-20
# 69   1955-05-13
# 70   1943-02-16
# 72   1943-04-17
# 73   1912-01-11
# 75   1913-01-06
# 76   1970-06-26
# 77   1964-08-30
# 78   1994-02-26
# 83   1947-11-19
# 85   1917-02-18
# 90   1924-01-20
# ...

# %%
df_antes_95 = df_concurso.loc[df_concurso['Data de Nascimento']< np.datetime64('1995')]
df_antes_95
# Out:
#                      Número de Inscrição Data de Nascimento  \
# 1   afd1d890-dbfd-4d72-a9a2-4309f356167a         1910-02-05
# 3   200731b4-a651-4a2d-9d01-11d4d6a41511         1949-11-21
# 4   22369508-74a2-403b-8237-1851971a08d6         1963-06-26
# 7   02899759-c6f1-45e3-bbad-6f4354f108f1         1965-08-06
# 9   b613c99e-113e-4e29-b2ff-c4a760096d6f         1923-04-18
# 10  d5853ead-5886-448f-b2fb-e0ac3ee9d4da         1968-05-11
# 13  3b49659d-ea37-43fa-a1d7-75786b33ccfe         1967-03-24
# 14  ce724367-0f16-43ef-baf4-64155dca3a25         1948-06-13
# 16  11fb4c71-809a-4327-a3f7-82c15bac0b36         1923-08-12
# 17  b6462017-e1a5-4a4b-963b-a26f16c7c91f         1988-10-28
# 18  36754e72-94f6-4bc1-bc92-f2460278bfd3         1929-04-16
# 20  17954cc3-454d-42f2-a39d-10600365dc4b         1951-07-24
# 22  15125837-e882-47a9-b279-0862707d3ec7         1928-02-08
# 23  06eb17b2-c804-49ad-bfc9-c1070a0dbf19         1984-03-04
# 26  e2c1defe-a2e3-46c8-b15c-06c0a94394d6         1971-04-10
# ...

# %%
df_10_primeiras = df_concurso.set_index('Data de Inscrição').sort_index()[:10]

# %%
df_concurso.sort_values('Data de Inscrição').iloc[:10, :]
# Out:
#                      Número de Inscrição   Data de Nascimento  \
# 6   1d6b237b-44d1-43d8-92c7-0825c3a02805     Falta Informação
# 11  26a5f7c3-f7bb-46d9-a9b2-0ca62429c56d  2000-07-09 00:00:00
# 30  d6a8ad8a-511a-46d7-ab54-e9ee1ce9f845  1941-09-25 00:00:00
# 79  a87116d6-215c-459d-b36d-04dea839d3fe     Falta Informação
# 41  cdebe031-88d0-4099-bfb2-47123c30ba15  2012-09-06 00:00:00
# 76  48b96931-5a54-4b6c-bbab-c46bc7e56957  1970-06-26 00:00:00
# 12  f3cae86a-4920-407f-9fcd-7317da8221e2  2016-03-10 00:00:00
# 42  0a1b5390-6ef7-442c-81cf-14754a0562a6  1947-11-26 00:00:00
# 34  b4dcd7a3-0682-4b81-80c0-28b74cf58187  1992-09-11 00:00:00
# 55  1060853a-7405-4058-bc9a-56cc6334f27c  1965-09-07 00:00:00
#
#       Data de Inscrição              Cidade            Estado Sexo  \
# 6   2022-01-05 07:21:28             Moreira                TO    F
# 11  2022-01-05 07:26:19    Falta Informação                RJ    F
# 30  2022-01-05 11:45:04    Freitas da Praia                RJ    F
# ...

# %% [markdown]
# # Valores faltosos
#
# 14. Para os valores faltosos coloque:
# - Se string: Falta informação
# - Se número: mediana
# 15. Plote a porcentagem de dados faltosos para cada coluna.

# %%
df_concurso.isna()
# Out:
#     Número de Inscrição  Data de Nascimento  Data de Inscrição  Cidade  \
# 0                 False               False              False   False
# 1                 False               False              False   False
# 2                 False               False              False   False
# 3                 False               False              False   False
# 4                 False               False              False   False
# ..                  ...                 ...                ...     ...
# 95                False               False              False   False
# 96                False               False              False   False
# 97                False               False              False   False
# 98                False               False              False   False
# 99                False               False              False   False
#
#     Estado   Sexo  Deficiência   Nome  Sobrenome  Escolaridade
# ...

# %%
df_concurso.columns
# Out:
# Index(['Número de Inscrição', 'Data de Nascimento', 'Data de Inscrição',
#        'Cidade', 'Estado', 'Sexo', 'Deficiência', 'Nome', 'Sobrenome',
#        'Escolaridade'],
#       dtype='object')

# %%
df_concurso.fillna('Falta Informação')
# Out:
#                      Número de Inscrição   Data de Nascimento  \
# 0   f2bf14e6-9ecc-43d1-9098-1a133277d26a     Falta Informação
# 1   afd1d890-dbfd-4d72-a9a2-4309f356167a  1910-02-05 00:00:00
# 2   16451a82-28f8-48bf-a5b6-9f0c5b25ef6b     Falta Informação
# 3   200731b4-a651-4a2d-9d01-11d4d6a41511  1949-11-21 00:00:00
# 4   22369508-74a2-403b-8237-1851971a08d6  1963-06-26 00:00:00
# ..                                   ...                  ...
# 95  b162a88d-6afa-46aa-afbe-f5b0e0d13ce4     Falta Informação
# 96  25e9b106-2c3d-444d-b7d4-ae34ad33bc88     Falta Informação
# 97  4ffbc174-78af-4da1-a53a-b442c20a876e     Falta Informação
# 98  d4e8e12a-3298-4ff1-a80f-2946431bd5a7  1916-06-21 00:00:00
# 99  7af3e5da-99a2-4f0f-900c-cbc194351ce8  1959-03-14 00:00:00
#
#       Data de Inscrição                Cidade            Estado  \
# 0   2022-01-11 16:47:41  da Mota de das Neves                MS
# 1   2022-01-30 13:17:53     Teixeira do Norte                SE
# ...

# %%
df_concurso['Estado'].unique()
# Out:
# array(['MS', 'SE', 'CE', 'RN', 'PA', 'ES', 'TO', 'PR', 'AM', 'MA', 'RJ',
#        'SP', 'Falta Informação', 'AP', 'PB', 'MG', 'MT', 'DF', 'BA', 'PI',
#        'RO', 'AL', 'SC', 'PE', 'GO', 'RR', 'RS'], dtype=object)

# %%
df_semna = df_concurso.fillna('Falta Informação')

# %%
df_semna['Estado'].unique()
# Out:
# array(['MS', 'SE', 'CE', 'RN', 'PA', 'ES', 'TO', 'PR', 'AM', 'MA', 'RJ',
#        'SP', 'Falta Informação', 'AP', 'PB', 'MG', 'MT', 'DF', 'BA', 'PI',
#        'RO', 'AL', 'SC', 'PE', 'GO', 'RR', 'RS'], dtype=object)

# %%
df_concurso.isna().sum()/100
# Out:
# Número de Inscrição    0.0
# Data de Nascimento     0.0
# Data de Inscrição      0.0
# Cidade                 0.0
# Estado                 0.0
# Sexo                   0.0
# Deficiência            0.0
# Nome                   0.0
# Sobrenome              0.0
# Escolaridade           0.0
# dtype: float64
